# %%
"""
A very simple example of optimizing a three-unknowns equation:

a/(b+c) +  b/(a+c) + c/(a+b) = 4

using natural evolution approaches.

@author: Haoxi Zhang
@verison: 0.01 beta
@date:   2018-7-29
"""

import numpy as np
from random import random, randint
from functools import reduce
from operator import add
np.random.seed(0)

# hyperparameters 
target = 4.0   # a/(b+c) +  b/(a+c) + c/(a+b) = 4
pop_size = 100 # population size
i_length = 3   # size of each individual
i_min = 1     
i_max = 1000

### fitness
def f_cell(a, b, c):
    """
    To avoid the divide-zero error 
    """
    try: return a / float(b + c)  
    except: return 100.0 # High means bad fitness in this case.

def fitness(individual, target):
    """
    Determine the fitness of an individual. 

    individual: the individual to evaluate
    target: the target number individuals are aiming for
    s : "strawberry" 
    b : "banana" 
    p : "pineapple"     
    """
    s = individual[0]
    b = individual[1]
    p = individual[2]
    i_fitness = f_cell(s,b,p) + f_cell(b,s,p) + f_cell(p,s,b)
    return abs(target - i_fitness)

def grade(pop, target):
    'Find average fitness for a population.'
    summed = reduce(add, (fitness(x, target) for x in pop))
    return summed / (len(pop) * 1.0)
### end fitness

# %%
def individual(length, min, max):
    'Create a member of the population.'
    return [ randint(min,max) for x in range(length) ]

def population(count, length, min, max):
    """
    Create a number of individuals (i.e. a population).

    count: the number of individuals in the population
    length: the number of values per individual
    min: the minimum possible value in an individual's list of values
    max: the maximum possible value in an individual's list of values

    """
    return [ individual(length, min, max) for x in range(count) ]

# %%
def evolve(pop, target, retain=0.2, random_select=0.05, mutate=0.01):
    graded = [ (fitness(x, target), x) for x in pop]
    graded = [ x[1] for x in sorted(graded)]
    retain_length = int(len(graded)*retain)
    parents = graded[:retain_length]
    # randomly add other individuals to
    # promote genetic diversity
    for individual in graded[retain_length:]:
        if random_select > random():
            parents.append(individual)
    # mutate some individuals
    for individual in parents:
        if mutate > random():
            pos_to_mutate = randint(0, len(individual)-1)
            # this mutation is not ideal, because it
            # restricts the range of possible values,
            # but the function is unaware of the min/max
            # values used to create the individuals,
            individual[pos_to_mutate] = randint(
                min(individual), max(individual))
    # crossover parents to create children
    parents_length = len(parents)
    desired_length = len(pop) - parents_length
    children = []
    while len(children) < desired_length:
        male = randint(0, parents_length-1)
        female = randint(0, parents_length-1)
        if male != female:
            male = parents[male]
            female = parents[female]
            half = int(len(male) / 2)
            child = male[:half] + female[half:]
            children.append(child)        
    parents.extend(children)
    return parents

# %%
p = population(pop_size, i_length, i_min, i_max)
fitness_history = [grade(p, target),]
best_pop = []
best_grade = 1
for i in range(5000):
    p = evolve(p, target)
    g = grade(p, target)
    fitness_history.append(g)
    if g < best_grade:
        best_pop = p
        best_grade = g

i = 0
for gen_grade in fitness_history:
    if i % 20 == 0:
        print('iter %d. Population fitness: %f' % 
              (i,  gen_grade ))
    i += 1

for idi in best_pop:
    print(idi)
    
print(best_grade)
# Out:
# iter 0. Population fitness: 2.146567
# iter 20. Population fitness: 0.430174
# iter 40. Population fitness: 0.178088
# iter 60. Population fitness: 0.141638
# iter 80. Population fitness: 0.289882
# iter 100. Population fitness: 0.139909
# iter 120. Population fitness: 0.139909
# iter 140. Population fitness: 0.146121
# iter 160. Population fitness: 0.139909
# iter 180. Population fitness: 0.155317
# iter 200. Population fitness: 0.314895
# iter 220. Population fitness: 0.210403
# iter 240. Population fitness: 0.139909
# iter 260. Population fitness: 0.167384
# iter 280. Population fitness: 0.139909
# iter 300. Population fitness: 0.060024
# iter 320. Population fitness: 0.015298
# iter 340. Population fitness: 0.015298
# iter 360. Population fitness: 0.101773
# iter 380. Population fitness: 0.015298
# iter 400. Population fitness: 0.015298
# iter 420. Population fitness: 0.138049
# iter 440. Population fitness: 0.015298
# iter 460. Population fitness: 0.015298
# iter 480. Population fitness: 0.015298
# iter 500. Population fitness: 0.015298
# iter 520. Population fitness: 0.015298
# iter 540. Population fitness: 0.015298
# iter 560. Population fitness: 0.015298
# iter 580. Population fitness: 0.015298
# iter 600. Population fitness: 0.246643
# iter 620. Population fitness: 0.015298
# iter 640. Population fitness: 0.125876
# iter 660. Population fitness: 0.015298
# iter 680. Population fitness: 0.095712
# iter 700. Population fitness: 0.015298
# iter 720. Population fitness: 0.064786
# iter 740. Population fitness: 0.015298
# iter 760. Population fitness: 0.016551
# iter 780. Population fitness: 0.015298
# iter 800. Population fitness: 0.015298
# iter 820. Population fitness: 0.015298
# iter 840. Population fitness: 0.076251
# iter 860. Population fitness: 0.015298
# iter 880. Population fitness: 0.015298
# iter 900. Population fitness: 0.076915
# iter 920. Population fitness: 0.015298
# iter 940. Population fitness: 0.042799
# iter 960. Population fitness: 0.015298
# iter 980. Population fitness: 0.015298
# iter 1000. Population fitness: 0.112862
# iter 1020. Population fitness: 0.078554
# iter 1040. Population fitness: 0.015298
# iter 1060. Population fitness: 0.015298
# iter 1080. Population fitness: 0.015298
# iter 1100. Population fitness: 0.015298
# iter 1120. Population fitness: 0.015298
# iter 1140. Population fitness: 0.015298
# iter 1160. Population fitness: 0.015298
# iter 1180. Population fitness: 0.165290
# iter 1200. Population fitness: 0.097183
# iter 1220. Population fitness: 0.015298
# iter 1240. Population fitness: 0.015298
# iter 1260. Population fitness: 0.015298
# iter 1280. Population fitness: 0.059663
# iter 1300. Population fitness: 0.015298
# iter 1320. Population fitness: 0.015298
# iter 1340. Population fitness: 0.015298
# iter 1360. Population fitness: 0.015298
# iter 1380. Population fitness: 0.015298
# iter 1400. Population fitness: 0.015298
# iter 1420. Population fitness: 0.015298
# iter 1440. Population fitness: 0.015298
# iter 1460. Population fitness: 0.015298
# iter 1480. Population fitness: 0.015298
# iter 1500. Population fitness: 0.015298
# iter 1520. Population fitness: 0.021836
# iter 1540. Population fitness: 0.015298
# iter 1560. Population fitness: 0.015298
# iter 1580. Population fitness: 0.015298
# iter 1600. Population fitness: 0.015298
# iter 1620. Population fitness: 0.034889
# iter 1640. Population fitness: 0.015298
# iter 1660. Population fitness: 0.015298
# iter 1680. Population fitness: 0.096402
# iter 1700. Population fitness: 0.165298
# iter 1720. Population fitness: 0.015298
# iter 1740. Population fitness: 0.076687
# iter 1760. Population fitness: 0.015298
# iter 1780. Population fitness: 0.015298
# iter 1800. Population fitness: 0.015298
# iter 1820. Population fitness: 0.092604
# iter 1840. Population fitness: 0.002804
# iter 1860. Population fitness: 0.002804
# iter 1880. Population fitness: 0.002804
# iter 1900. Population fitness: 0.002804
# iter 1920. Population fitness: 0.086307
# iter 1940. Population fitness: 0.002804
# iter 1960. Population fitness: 0.002804
# iter 1980. Population fitness: 0.002804
# iter 2000. Population fitness: 0.068592
# iter 2020. Population fitness: 0.048423
# iter 2040. Population fitness: 0.052742
# iter 2060. Population fitness: 0.002804
# iter 2080. Population fitness: 0.002804
# iter 2100. Population fitness: 0.002804
# iter 2120. Population fitness: 0.002804
# iter 2140. Population fitness: 0.002804
# iter 2160. Population fitness: 0.002804
# iter 2180. Population fitness: 0.056901
# iter 2200. Population fitness: 0.002804
# iter 2220. Population fitness: 0.002804
# iter 2240. Population fitness: 0.002804
# iter 2260. Population fitness: 0.002804
# iter 2280. Population fitness: 0.002804
# iter 2300. Population fitness: 0.002804
# iter 2320. Population fitness: 0.002804
# iter 2340. Population fitness: 0.085477
# iter 2360. Population fitness: 0.058802
# iter 2380. Population fitness: 0.008960
# iter 2400. Population fitness: 0.002804
# iter 2420. Population fitness: 0.052965
# iter 2440. Population fitness: 0.002804
# iter 2460. Population fitness: 0.002804
# iter 2480. Population fitness: 0.002804
# iter 2500. Population fitness: 0.091045
# iter 2520. Population fitness: 0.046551
# iter 2540. Population fitness: 0.002804
# iter 2560. Population fitness: 0.002804
# iter 2580. Population fitness: 0.045310
# iter 2600. Population fitness: 0.002804
# iter 2620. Population fitness: 0.073821
# iter 2640. Population fitness: 0.059214
# iter 2660. Population fitness: 0.002804
# iter 2680. Population fitness: 0.002804
# iter 2700. Population fitness: 0.002804
# iter 2720. Population fitness: 0.002804
# iter 2740. Population fitness: 0.002804
# iter 2760. Population fitness: 0.046225
# iter 2780. Population fitness: 0.002804
# iter 2800. Population fitness: 0.085517
# iter 2820. Population fitness: 0.002804
# iter 2840. Population fitness: 0.002804
# iter 2860. Population fitness: 0.011568
# iter 2880. Population fitness: 0.002804
# iter 2900. Population fitness: 0.002804
# iter 2920. Population fitness: 0.002804
# iter 2940. Population fitness: 0.026830
# iter 2960. Population fitness: 0.074260
# iter 2980. Population fitness: 0.002804
# iter 3000. Population fitness: 0.002804
# iter 3020. Population fitness: 0.032139
# iter 3040. Population fitness: 0.002804
# iter 3060. Population fitness: 0.087445
# iter 3080. Population fitness: 0.002804
# iter 3100. Population fitness: 0.002804
# iter 3120. Population fitness: 0.002804
# iter 3140. Population fitness: 0.002804
# iter 3160. Population fitness: 0.003476
# iter 3180. Population fitness: 0.081805
# iter 3200. Population fitness: 0.002804
# iter 3220. Population fitness: 0.002804
# iter 3240. Population fitness: 0.002804
# iter 3260. Population fitness: 0.002804
# iter 3280. Population fitness: 0.002804
# iter 3300. Population fitness: 0.009751
# iter 3320. Population fitness: 0.002804
# iter 3340. Population fitness: 0.002804
# iter 3360. Population fitness: 0.051554
# iter 3380. Population fitness: 0.002804
# iter 3400. Population fitness: 0.002804
# iter 3420. Population fitness: 0.176462
# iter 3440. Population fitness: 0.024685
# iter 3460. Population fitness: 0.002804
# iter 3480. Population fitness: 0.002804
# iter 3500. Population fitness: 0.002804
# iter 3520. Population fitness: 0.110240
# iter 3540. Population fitness: 0.002804
# iter 3560. Population fitness: 0.046353
# iter 3580. Population fitness: 0.002804
# iter 3600. Population fitness: 0.002804
# iter 3620. Population fitness: 0.002804
# iter 3640. Population fitness: 0.153627
# iter 3660. Population fitness: 0.136487
# iter 3680. Population fitness: 0.002804
# iter 3700. Population fitness: 0.002804
# iter 3720. Population fitness: 0.044080
# iter 3740. Population fitness: 0.123886
# iter 3760. Population fitness: 0.283241
# iter 3780. Population fitness: 0.114115
# iter 3800. Population fitness: 0.002804
# iter 3820. Population fitness: 0.002804
# iter 3840. Population fitness: 0.076027
# iter 3860. Population fitness: 0.002804
# iter 3880. Population fitness: 0.078821
# iter 3900. Population fitness: 0.002804
# iter 3920. Population fitness: 0.050760
# iter 3940. Population fitness: 0.002804
# iter 3960. Population fitness: 0.027865
# iter 3980. Population fitness: 0.002804
# iter 4000. Population fitness: 0.002804
# iter 4020. Population fitness: 0.002804
# iter 4040. Population fitness: 0.002804
# iter 4060. Population fitness: 0.002804
# iter 4080. Population fitness: 0.002804
# iter 4100. Population fitness: 0.156018
# iter 4120. Population fitness: 0.002804
# iter 4140. Population fitness: 0.030614
# iter 4160. Population fitness: 0.002804
# iter 4180. Population fitness: 0.069913
# iter 4200. Population fitness: 0.002804
# iter 4220. Population fitness: 0.002804
# iter 4240. Population fitness: 0.002804
# iter 4260. Population fitness: 0.002804
# iter 4280. Population fitness: 0.002804
# iter 4300. Population fitness: 0.005301
# iter 4320. Population fitness: 0.002804
# iter 4340. Population fitness: 0.029254
# iter 4360. Population fitness: 0.002804
# iter 4380. Population fitness: 0.002804
# iter 4400. Population fitness: 0.002804
# iter 4420. Population fitness: 0.002804
# iter 4440. Population fitness: 0.002804
# iter 4460. Population fitness: 0.002804
# iter 4480. Population fitness: 0.002804
# iter 4500. Population fitness: 0.002804
# iter 4520. Population fitness: 0.002804
# iter 4540. Population fitness: 0.002804
# iter 4560. Population fitness: 0.002804
# iter 4580. Population fitness: 0.108456
# iter 4600. Population fitness: 0.076427
# iter 4620. Population fitness: 0.002804
# iter 4640. Population fitness: 0.002804
# iter 4660. Population fitness: 0.002804
# iter 4680. Population fitness: 0.002804
# iter 4700. Population fitness: 0.154707
# iter 4720. Population fitness: 0.055368
# iter 4740. Population fitness: 0.002804
# iter 4760. Population fitness: 0.002804
# iter 4780. Population fitness: 0.042972
# iter 4800. Population fitness: 0.095732
# iter 4820. Population fitness: 0.002804
# iter 4840. Population fitness: 0.002804
# iter 4860. Population fitness: 0.002804
# iter 4880. Population fitness: 0.002804
# iter 4900. Population fitness: 0.002804
# iter 4920. Population fitness: 0.029870
# iter 4940. Population fitness: 0.080128
# iter 4960. Population fitness: 0.002804
# iter 4980. Population fitness: 0.030468
# iter 5000. Population fitness: 0.002804
# [38, 430, 155]
# [174, 725, 155]
# [38, 725, 681]
# [38, 333, 155]
# [38, 725, 713]
# [38, 414, 155]
# [290, 725, 155]
# [38, 556, 155]
# [38, 725, 266]
# [38, 725, 195]
# [311, 725, 155]
# [38, 725, 589]
# [516, 725, 155]
# [392, 725, 155]
# [38, 430, 155]
# [38, 725, 545]
# [38, 426, 155]
# [38, 725, 681]
# [38, 642, 155]
# [500, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [149, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# [38, 725, 155]
# 0.0028039804944777202

# %%
a = 38
b = 725
c = 155

# %%
a/(b+c) +  b/(a+c) + c/(a+b)
# Out:
# 4.002803980494478
